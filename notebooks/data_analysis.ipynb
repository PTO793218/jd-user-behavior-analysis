# %%
#导包
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
import jieba
from collections import Counter
from wordcloud import WordCloud
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "d:\swu\Anaconda\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "d:\swu\Anaconda\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "d:\swu\Anaconda\Lib\asyncio\windows_events.py", line 322, in run_forever
#     super().run_forever()
#   File "d:\swu\Anaconda\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "d:\swu\Anaconda\Lib\asyncio\base_events.py", line 1987, in _run_once
#     handle._run()
#   File "d:\swu\Anaconda\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\swu\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "d:\swu\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "d:\swu\Anaconda\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\swu\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\swu\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\swu\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\potato\AppData\Local\Temp\ipykernel_24208\3035676431.py", line 2, in <module>
#     import pandas as pd
#   File "d:\swu\Anaconda\Lib\site-packages\pandas\__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "d:\swu\Anaconda\Lib\site-packages\pandas\compat\__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "d:\swu\Anaconda\Lib\site-packages\pandas\compat\pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "d:\swu\Anaconda\Lib\site-packages\pyarrow\__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File d:\swu\Anaconda\Lib\site-packages\numpy\core\_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "d:\swu\Anaconda\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "d:\swu\Anaconda\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "d:\swu\Anaconda\Lib\asyncio\windows_events.py", line 322, in run_forever
#     super().run_forever()
#   File "d:\swu\Anaconda\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "d:\swu\Anaconda\Lib\asyncio\base_events.py", line 1987, in _run_once
#     handle._run()
#   File "d:\swu\Anaconda\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\swu\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "d:\swu\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "d:\swu\Anaconda\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\swu\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\swu\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\swu\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\potato\AppData\Local\Temp\ipykernel_24208\3035676431.py", line 2, in <module>
#     import pandas as pd
#   File "d:\swu\Anaconda\Lib\site-packages\pandas\__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "d:\swu\Anaconda\Lib\site-packages\pandas\core\api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "d:\swu\Anaconda\Lib\site-packages\pandas\core\dtypes\dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "d:\swu\Anaconda\Lib\site-packages\pyarrow\__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File d:\swu\Anaconda\Lib\site-packages\numpy\core\_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "d:\swu\Anaconda\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "d:\swu\Anaconda\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "d:\swu\Anaconda\Lib\asyncio\windows_events.py", line 322, in run_forever
#     super().run_forever()
#   File "d:\swu\Anaconda\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "d:\swu\Anaconda\Lib\asyncio\base_events.py", line 1987, in _run_once
#     handle._run()
#   File "d:\swu\Anaconda\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\swu\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "d:\swu\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "d:\swu\Anaconda\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\swu\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\swu\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\swu\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\potato\AppData\Local\Temp\ipykernel_24208\3035676431.py", line 2, in <module>
#     import pandas as pd
#   File "d:\swu\Anaconda\Lib\site-packages\pandas\__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "d:\swu\Anaconda\Lib\site-packages\pandas\core\api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "d:\swu\Anaconda\Lib\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "d:\swu\Anaconda\Lib\site-packages\pandas\core\arrays\arrow\__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "d:\swu\Anaconda\Lib\site-packages\pandas\core\arrays\arrow\array.py", line 52, in <module>
#     from pandas.core import (
#   File "d:\swu\Anaconda\Lib\site-packages\pandas\core\ops\__init__.py", line 8, in <module>
#     from pandas.core.ops.array_ops import (
#   File "d:\swu\Anaconda\Lib\site-packages\pandas\core\ops\array_ops.py", line 56, in <module>
#     from pandas.core.computation import expressions
#   File "d:\swu\Anaconda\Lib\site-packages\pandas\core\computation\expressions.py", line 21, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "d:\swu\Anaconda\Lib\site-packages\pandas\core\computation\check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "d:\swu\Anaconda\Lib\site-packages\pandas\compat\_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "d:\swu\Anaconda\Lib\importlib\__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "d:\swu\Anaconda\Lib\site-packages\numexpr\__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "d:\swu\Anaconda\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "d:\swu\Anaconda\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "d:\swu\Anaconda\Lib\asyncio\windows_events.py", line 322, in run_forever
#     super().run_forever()
#   File "d:\swu\Anaconda\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "d:\swu\Anaconda\Lib\asyncio\base_events.py", line 1987, in _run_once
#     handle._run()
#   File "d:\swu\Anaconda\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "d:\swu\Anaconda\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\swu\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "d:\swu\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "d:\swu\Anaconda\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\swu\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\swu\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\swu\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\potato\AppData\Local\Temp\ipykernel_24208\3035676431.py", line 2, in <module>
#     import pandas as pd
#   File "d:\swu\Anaconda\Lib\site-packages\pandas\__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "d:\swu\Anaconda\Lib\site-packages\pandas\core\api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "d:\swu\Anaconda\Lib\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "d:\swu\Anaconda\Lib\site-packages\pandas\core\arrays\arrow\__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "d:\swu\Anaconda\Lib\site-packages\pandas\core\arrays\arrow\array.py", line 66, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "d:\swu\Anaconda\Lib\site-packages\pandas\core\arrays\masked.py", line 61, in <module>
#     from pandas.core import (
#   File "d:\swu\Anaconda\Lib\site-packages\pandas\core\nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "d:\swu\Anaconda\Lib\site-packages\pandas\compat\_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "d:\swu\Anaconda\Lib\importlib\__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "d:\swu\Anaconda\Lib\site-packages\bottleneck\__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File d:\swu\Anaconda\Lib\site-packages\numpy\core\_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.

# %%
#1.导入文件
df = pd.read_csv(r'../data/raw/UserBehavior--1.csv', encoding='gb18030')
print(df.head())
print(df.shape)
print(df.info())
print(df.describe())
# Out:
# C:\Users\potato\AppData\Local\Temp\ipykernel_24208\3432964538.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'../data/raw/UserBehavior--1.csv', encoding='gb18030')
#    user_id  goods_id  category_id behavior   timestamp  sex address device  \
# 0   866796   5002615      2520377       pv  1716991385    0      成都  Redmi
# 1   866796   2734026      4145813       pv  1716994184    0      成都  Redmi
# 2   866796   5002615      2520377       pv  1716996273    0      成都  Redmi
# 3   866796   3239041      2355072       pv  1717007664    0      成都  Redmi
# 4   866796   4615417      4145813       pv  1717022864    0      成都  Redmi
#
#    price  amount comment
# 0    0.0       0     NaN
# 1    0.0       0     NaN
# 2    0.0       0     NaN
# 3    0.0       0     NaN
# 4    0.0       0     NaN
# (764833, 11)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 764833 entries, 0 to 764832
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   user_id      764833 non-null  int64
#  1   goods_id     764833 non-null  int64
#  2   category_id  764833 non-null  int64
#  3   behavior     764833 non-null  object
#  4   timestamp    764833 non-null  object
#  5   sex          764833 non-null  int64
#  6   address      757565 non-null  object
#  7   device       764833 non-null  object
#  8   price        764833 non-null  float64
#  9   amount       764833 non-null  int64
#  10  comment      14582 non-null   object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 64.2+ MB
# None
#              user_id      goods_id   category_id            sex  \
# count  764833.000000  7.648330e+05  7.648330e+05  764833.000000
# mean     5761.424472  2.140078e+06  2.710476e+06       0.428552
# std      9197.119971  5.410040e+06  1.459465e+06       0.494869
# min         2.000000 -8.991309e+07  2.171000e+03       0.000000
# 25%      2849.000000  1.266711e+06  1.379146e+06       0.000000
# 50%      5711.000000  2.559592e+06  2.690374e+06       0.000000
# 75%      8396.000000  3.848816e+06  4.145813e+06       1.000000
# max    937166.000000  5.163006e+06  5.161669e+06       1.000000
#
#                price         amount
# count  764833.000000  764833.000000
# mean        0.946255       0.047527
# std         7.878176       0.374452
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# 75%         0.000000       0.000000
# max        99.900000       4.000000

# %%
# 2.数据清洗-----检查重复值
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#检查缺失值
df.isnull().sum()
# Out:
# user_id             0
# goods_id            0
# category_id         0
# behavior            0
# timestamp           0
# sex                 0
# address          7268
# device              0
# price               0
# amount              0
# comment        750251
# dtype: int64

# %%
# 地址缺失用“未知”填充
df['address'] = df['address'].fillna('未知')

# 评论缺失不用删
df['comment'] = df['comment'].fillna('无评论')

# %%
# 转换时间戳，异常值变NaT
df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s', errors='coerce')
#删除时间为空的行
df = df.dropna(subset=['timestamp'])
# Out:
# C:\Users\potato\AppData\Local\Temp\ipykernel_24208\1245967638.py:2: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s', errors='coerce')

# %%
#拆时间维度
df['date'] = df['timestamp'].dt.date
df['hour'] = df['timestamp'].dt.hour
df['month'] = df['timestamp'].dt.month
df['weekday'] = df['timestamp'].dt.day_name()

# %%
#goods_id字段处理
df[df['goods_id'] < 0]     #之前的数据处理正好清除goods_id负值异常，结果为0
# Out:
# Empty DataFrame
# Columns: [user_id, goods_id, category_id, behavior, timestamp, sex, address, device, price, amount, comment, date, hour, month, weekday]
# Index: []

# %%
#price字段处理
df[(df['behavior']=='buy') & (df['price']==0)]  #11, 15
df = df[~((df['behavior']=='buy') & (df['price']==0))]

# %%
#amount字段处理
df[(df['behavior']=='buy') & (df['amount']==0)]  #结果为0
# Out:
# Empty DataFrame
# Columns: [user_id, goods_id, category_id, behavior, timestamp, sex, address, device, price, amount, comment, date, hour, month, weekday]
# Index: []

# %%
#统一字段行为
df['behavior'].value_counts() #正常
# Out:
# 用户数量: 10739
# 商品数量: 327582

# %%
#新增销售额字段
df['sales'] = df['price'] * df['amount']

#查看用户数量和商品数量
print('用户数量:',df['user_id'].nunique())
print('商品数量:',df['goods_id'].nunique())

df.to_csv('../data/processed/clean_jd_data.csv', index=False, encoding='utf-8-sig')

# %%
#3.用户行为分析----用户行为柱状图
behavior_count = df['behavior'].value_counts()
print(behavior_count)

behavior_count.plot(kind='bar')
plt.title('User Behavior Distribution')
plt.xlabel('Behavior')
plt.ylabel('Count')
plt.show()
# Out:
# behavior
# pv      679668
# cart     42714
# fav      20601
# buy      14571
# Name: count, dtype: int64

# %%
#用户行为饼状图
behavior_count.plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(8,8)
)

plt.ylabel('')
plt.title('Behavior Ratio')
plt.show()

# %%
#转化漏斗分析
pv = behavior_count['pv']
cart = behavior_count['cart']
fav = behavior_count['fav']
buy = behavior_count['buy']

cart_rate = cart / pv
fav_rate = fav / pv
buy_rate = buy / pv

print("加购率：", cart_rate)
print("收藏率：", fav_rate)
print("购买率：", buy_rate)
# Out:
# 加购率： 0.06284538921944244
# 收藏率： 0.030310386835925775
# 购买率： 0.021438408163985945

# %%
#4.时间趋势分析----日行为趋势
daily_behavior = df.groupby('date').size()
print(daily_behavior)

daily_behavior.plot(figsize=(12,6))
plt.title('Daily User Activity')
plt.xlabel('Date')
plt.ylabel('Count')
plt.show()
# Out:
# date
# 2024-05-29     85580
# 2024-05-30    110772
# 2024-05-31    112782
# 2024-06-01    119463
# 2024-06-02    147576
# 2024-06-03    153523
# 2024-06-04     27858
# dtype: int64

# %%
#小时行为趋势
hour_behavior = df.groupby('hour').size()
print(hour_behavior)

hour_behavior.plot(figsize=(12,6))
plt.title('Hourly Activity')
plt.xlabel('Hour')
plt.ylabel('Count')
plt.show()
# Out:
# hour
# 0     65290
# 1     56933
# 2     40024
# 3     19310
# 4      8834
# 5      4951
# 6      4125
# 7      4025
# 8      6152
# 9     13078
# 10    21156
# 11    26979
# 12    33056
# 13    37447
# 14    34742
# 15    39549
# 16    38503
# 17    40059
# 18    40611
# 19    38038
# 20    34961
# 21    38653
# 22    50613
# 23    60465
# dtype: int64

# %%
#5.商品分析----TOP销量商品分析
top_goods = df[df['behavior']=='buy'].groupby('goods_id')['amount'].sum().sort_values(ascending=False).head(10)
print(top_goods)

top_goods.plot(kind='bar', figsize=(12,6))
plt.title('Top 10 Goods by Sales Volume')
plt.xlabel('Goods ID')
plt.ylabel('Sales Volume')
plt.show()
# Out:
# goods_id
# 3122135    41
# 2356549    26
# 1728241    20
# 1535294    17
# 1116492    17
# 2964774    17
# 2101968    16
# 3242045    15
# 3244134    15
# 2588261    15
# Name: amount, dtype: int64

# %%
#TOP销售额商品分析
top_sales_goods = df.groupby('goods_id')['sales'].sum().sort_values(ascending=False).head(10)
print(top_sales_goods)

top_sales_goods.plot(kind='bar', figsize=(12,6))
plt.title('Top 10 Goods by Revenue')
plt.xlabel('Goods ID')
plt.ylabel('Revenue')
plt.show()
# Out:
# goods_id
# 2101968    1548.8
# 2356549    1427.4
# 3665944    1321.6
# 2964774    1315.8
# 2955846    1184.4
# 403950     1140.0
# 740947     1041.7
# 1754834    1000.8
# 4803882     970.2
# 2715942     942.0
# Name: sales, dtype: float64

# %%
#TOP热门品类分析
top_category = df['category_id'].value_counts().head(10)
print(top_category)

top_category.plot(kind='bar', figsize=(12,6))
plt.title('Top 10 Categories by Activity')
plt.xlabel('Category ID')
plt.ylabel('Count')
plt.show()
# Out:
# category_id
# 4756105    41444
# 4145813    28497
# 2355072    25264
# 982926     24241
# 3607361    23445
# 2520377    17985
# 4801426    16756
# 1320293    14865
# 3002561    13206
# 2465336    11826
# Name: count, dtype: int64

# %%
#TOP销售品类分析
category_sales = df.groupby('category_id')['sales'].sum().sort_values(ascending=False).head(10)
print(category_sales)

category_sales.plot(kind='bar', figsize=(12,6))
plt.title('Top 10 Categories by Revenue')
plt.xlabel('Category ID')
plt.ylabel('Revenue')
plt.show()
# Out:
# category_id
# 2735466    34679.0
# 4756105    31328.3
# 1464116    29884.5
# 4145813    28337.0
# 4801426    27836.0
# 2885642    24053.7
# 982926     20439.4
# 4159072    18340.5
# 2640118    17536.5
# 3002561    16150.6
# Name: sales, dtype: float64

# %%
#6.用户价值分析----高消费用户分析
user_sales = df.groupby('user_id')['sales'].sum().sort_values(ascending=False).head(10)
print(user_sales)

user_sales.plot(kind='bar', figsize=(12,6))
plt.title('Top 10 Users by Revenue')
plt.xlabel('User ID')
plt.ylabel('Revenue')
plt.show()
# Out:
# user_id
# 9610    4726.8
# 4762    3933.2
# 2021    3906.4
# 3745    3536.1
# 50      3154.4
# 7633    3143.1
# 8515    3097.8
# 4410    2655.8
# 9422    2522.7
# 4147    2507.2
# Name: sales, dtype: float64

# %%
#购买次数最多用户
top_buy_users = df[df['behavior']=='buy']['user_id'].value_counts().head(10)
print(top_buy_users)

top_buy_users.plot(kind='bar', figsize=(12,6))
plt.title('Top 10 Users by Purchase Frequency')
plt.xlabel('User ID')
plt.ylabel('Purchase Count')
plt.show()
# Out:
# user_id
# 9610    45
# 4762    32
# 3745    31
# 2021    25
# 7633    23
# 9422    22
# 470     21
# 8515    20
# 50      18
# 822     18
# Name: count, dtype: int64

# %%
#客单价分析
avg_order_value = df[df['behavior']=='buy']['sales'].sum() / len(df[df['behavior']=='buy'])
print(avg_order_value)
# Out:
# 123.9331205819779

# %%
#用户消费分层
user_total_sales = df.groupby('user_id')['sales'].sum()
print(user_total_sales.describe())

user_level = pd.cut(
    user_total_sales,
    bins=[0,50,200,1000,10000],
    labels=['低消费','中消费','高消费','超级用户']
)

print(user_level.value_counts())
# Out:
# count    10739.000000
# mean       168.156206
# std        275.630840
# min          0.000000
# 25%          0.000000
# 50%         49.300000
# 75%        247.650000
# max       4726.800000
# Name: sales, dtype: float64
# sales
# 高消费     2933
# 中消费     2221
# 低消费      753
# 超级用户     201
# Name: count, dtype: int64

# %%
#7.RFM用户价值模型----筛选购买数据
buy_df = df[df['behavior']=='buy'].copy()

#构建R
snapshot_date = buy_df['timestamp'].max() + pd.Timedelta(days=1)
print(snapshot_date)

R = buy_df.groupby('user_id')['timestamp'].max()
R = (snapshot_date - R).dt.days
print(R.head())
# Out:
# 2024-06-05 02:39:23
# user_id
# 2     2
# 4     4
# 16    3
# 17    3
# 20    3
# Name: timestamp, dtype: int64

# %%
#构建F
F = buy_df.groupby('user_id').size()
print(F.head())
# Out:
# user_id
# 2     7
# 4     4
# 16    2
# 17    1
# 20    1
# dtype: int64

# %%
#构建M
M = buy_df.groupby('user_id')['sales'].sum()
print(M.head())
# Out:
# user_id
# 2     1307.2
# 4      570.4
# 16     169.3
# 17      62.7
# 20      37.9
# Name: sales, dtype: float64

# %%
#合并RFM
rfm = pd.concat([R,F,M], axis=1)
rfm.columns = ['R','F','M']

# %%
#构建用户标签
rfm['R_score'] = rfm['R'].apply(
    lambda x: 1 if x <= rfm['R'].median() else 0
)
rfm['F_score'] = rfm['F'].apply(
    lambda x: 1 if x >= rfm['F'].median() else 0
)
rfm['M_score'] = rfm['M'].apply(
    lambda x: 1 if x >= rfm['M'].median() else 0
)

rfm['RFM'] = (
    rfm['R_score'].astype(str) +
    rfm['F_score'].astype(str) +
    rfm['M_score'].astype(str)
)
print(rfm.head())
print(rfm['RFM'].value_counts())
# Out:
#          R  F       M  R_score  F_score  M_score  RFM
# user_id
# 2        2  7  1307.2        1        1        1  111
# 4        4  4   570.4        0        1        1  011
# 16       3  2   169.3        0        1        0  010
# 17       3  1    62.7        0        0        0  000
# 20       3  1    37.9        0        0        0  000
# RFM
# 111    1720
# 000    1278
# 100     919
# 011     842
# 110     513
# 010     344
# 001     296
# 101     196
# Name: count, dtype: int64

# %%
#建立用户标签映射
def rfm_label(x):
    if x == '111':
        return '核心价值用户'
    elif x == '110':
        return '高潜力用户'
    elif x == '101':
        return '高消费流失预警用户'
    elif x == '100':
        return '一般发展用户'
    elif x == '011':
        return '重点保持用户'
    elif x == '010':
        return '一般保持用户'
    elif x == '001':
        return '高消费沉睡用户'
    else:
        return '流失用户'

rfm['label'] = rfm['RFM'].apply(rfm_label)

label_count = rfm['label'].value_counts()
print(label_count)
# Out:
# label
# 核心价值用户       1720
# 流失用户         1278
# 一般发展用户        919
# 重点保持用户        842
# 高潜力用户         513
# 一般保持用户        344
# 高消费沉睡用户       296
# 高消费流失预警用户     196
# Name: count, dtype: int64

# %%
#画用户标签映射柱状图
label_count.plot(
    kind='bar',
    figsize=(12,6)
)

plt.title('RFM User Segmentation')
plt.xlabel('User Segment')
plt.ylabel('Count')
plt.show()

# %%
#8.地区分析----地区活跃度分析
area_active = df['address'].value_counts().head(10)
print(area_active)

area_active.plot(kind='bar', figsize=(12,6))
plt.title('Top 10 Active Areas')
plt.xlabel('Area')
plt.ylabel('Activity Count')
plt.show()
# Out:
# address
# 南宁    180456
# 珠海     89718
# 深圳     62930
# 成都     60334
# 上海     56155
# 武汉     55837
# 广州     54268
# 佛山     53475
# 南京     45087
# 北京     42478
# Name: count, dtype: int64

# %%
#地区销售额分析
area_sales = df.groupby('address')['sales'].sum().sort_values(ascending=False).head(10)
print(area_sales)

area_sales.plot(kind='bar', figsize=(12,6))
plt.title('Top 10 Areas by Revenue')
plt.xlabel('Area')
plt.ylabel('Revenue')
plt.show()
# Out:
# address
# 南宁    428730.4
# 珠海    211754.3
# 成都    159108.2
# 深圳    148633.1
# 佛山    136478.9
# 上海    127269.1
# 武汉    125684.2
# 广州    124889.9
# 北京    109967.0
# 南京    102110.6
# Name: sales, dtype: float64

# %%
#地区购买次数分析
area_buy = df[df['behavior']=='buy']['address'].value_counts().head(10)
print(area_buy)

area_buy.plot(kind='bar', figsize=(12,6))
plt.title('Top 10 Areas by Purchase Count')
plt.xlabel('Area')
plt.ylabel('Purchase Count')
plt.show()
# Out:
# address
# 南宁    3450
# 珠海    1747
# 成都    1302
# 深圳    1236
# 佛山    1148
# 武汉    1036
# 上海    1011
# 广州     950
# 北京     866
# 南京     798
# Name: count, dtype: int64

# %%
#9.设备分析----设备活跃度分析
device_active = df['device'].value_counts()
print(device_active)

device_active.plot(kind='bar', figsize=(12,6))
plt.title('Device Activity Distribution')
plt.xlabel('Device')
plt.ylabel('Count')
plt.show()
# Out:
# device
# 荣耀        180456
# moto       89718
# 小米         62930
# Redmi      60334
# 魅族         56155
# iPhone     55837
# OPPO       54268
# HUAWEI     53475
# vivo       45087
# 三星         42478
# 一加         31715
# 联想         25101
# Name: count, dtype: int64

# %%
#设备购买次数分析
device_buy = df[df['behavior']=='buy']['device'].value_counts()
print(device_buy)

device_buy.plot(kind='bar', figsize=(12,6))
plt.title('Device Purchase Distribution')
plt.xlabel('Device')
plt.ylabel('Purchase Count')
plt.show()
# Out:
# device
# 荣耀        3450
# moto      1747
# Redmi     1302
# 小米        1236
# HUAWEI    1148
# iPhone    1036
# 魅族        1011
# OPPO       950
# 三星         866
# vivo       798
# 一加         529
# 联想         498
# Name: count, dtype: int64

# %%
#设备销售额分析
device_sales = df.groupby('device')['sales'].sum().sort_values(ascending=False)
print(device_sales)

device_sales.plot(kind='bar', figsize=(12,6))
plt.title('Device Revenue Distribution')
plt.xlabel('Device')
plt.ylabel('Revenue')
plt.show()
# Out:
# device
# 荣耀        428730.4
# moto      211754.3
# Redmi     159108.2
# 小米        148633.1
# HUAWEI    136478.9
# 魅族        127269.1
# iPhone    125684.2
# OPPO      124889.9
# 三星        109967.0
# vivo      102110.6
# 一加         67880.4
# 联想         63323.4
# Name: sales, dtype: float64

# %%
#设备转化率分析
device_conversion = device_buy / device_active
print(device_conversion)
# Out:
# device
# HUAWEI    0.021468
# OPPO      0.017506
# Redmi     0.021580
# iPhone    0.018554
# moto      0.019472
# vivo      0.017699
# 一加        0.016680
# 三星        0.020387
# 小米        0.019641
# 联想        0.019840
# 荣耀        0.019118
# 魅族        0.018004
# Name: count, dtype: float64

# %%
#10.评论分析----评论数量分析
comment_df = df[df['comment'] != '无评论'].copy()
print(comment_df.shape)
comment_count = comment_df.shape[0]
print(comment_count)
# Out:
# (14571, 16)
# 14571

# %%
#高频词分析
#拼接文本
text = ''.join(comment_df['comment'].astype(str))
#分词
words = jieba.lcut(text)
print(words[:50])
#过滤停用词
stopwords = ['的','了','很','也','是','都',
    '一个','这个','就是','还是',
    '什么','没有','不是','知道']
words = [w for w in words if w not in stopwords and len(w) > 1]
#统计词频
word_count = Counter(words)
print(word_count.most_common(20))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\potato\AppData\Local\Temp\jieba.cache
# Loading model cost 0.684 seconds.
# Prefix dict has been built successfully.
# ['最近', '一直', '在', '看', '，', '昨天', '一口气', '看', '了', '3', '章', '建议', '怀孕', '末期', '的', '准爸', '准妈们', '都', '买', '本来', '看看', '通过', '这', '本书', ' ', '了解', '了', '孩子', '的', '一些', '行为', '其实', '孩子', '的', '一些', '行为', '不', '一定', '就是', '老人', '嘴里', '说', '的', '那样', '孩子', '每个', '动作', '都', '是', '主动']
# [('京东', 3074), ('不错', 2738), ('苹果', 1868), ('可以', 1562), ('感觉', 1284), ('东西', 1265), ('非常', 1201), ('喜欢', 1180), ('手机', 1125), ('快递', 945), ('包装', 932), ('一直', 893), ('本书', 855), ('收到', 831), ('自己', 820), ('而且', 812), ('但是', 776), ('真的', 722), ('速度', 706), ('问题', 704)]

# %%
#词云图
wc = WordCloud(
    font_path='simhei.ttf',
    width=1000,
    height=600
)
wc.generate(' '.join(words))

plt.figure(figsize=(12,6))
plt.imshow(wc)
plt.axis('off')
plt.show()

# %%
df.to_csv(
    '../data/processed/jd_analysis_final.csv',
    index=False,
    encoding='utf-8-sig'
)

# %%
rfm.to_csv(
    '../data/processed/jd_rfm_result.csv',
    encoding='utf-8-sig'
)

# %%
# 把词频转成DataFrame
word_freq_df = pd.DataFrame(word_count.most_common(100), columns=["word", "count"])

# 保存成 CSV 文件（直接可导入Tableau）
word_freq_df.to_csv("../data/processed/comment_word_freq.csv", index=False, encoding="utf-8-sig")
print("词频文件已生成：../data/processed/comment_word_freq.csv")
# Out:
# 词频文件已生成：../data/processed/comment_word_freq.csv
